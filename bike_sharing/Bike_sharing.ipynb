# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn import tree
from sklearn.metrics import confusion_matrix
from sklearn.ensemble import RandomForestClassifier

# %%
df=pd.read_csv('hour.csv')

# %%
df
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 0            1  2011-01-01       1   0     1   0        0        6
# 1            2  2011-01-01       1   0     1   1        0        6
# 2            3  2011-01-01       1   0     1   2        0        6
# 3            4  2011-01-01       1   0     1   3        0        6
# 4            5  2011-01-01       1   0     1   4        0        6
# ...        ...         ...     ...  ..   ...  ..      ...      ...
# 17374    17375  2012-12-31       1   1    12  19        0        1
# 17375    17376  2012-12-31       1   1    12  20        0        1
# 17376    17377  2012-12-31       1   1    12  21        0        1
# 17377    17378  2012-12-31       1   1    12  22        0        1
# 17378    17379  2012-12-31       1   1    12  23        0        1
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 0               0           1  0.24  0.2879  0.81     0.0000       3
# ...

# %%
df=df.drop(['dteday', 'instant'], axis='columns')

# %%
df
# Out:
#        season  yr  mnth  hr  holiday  weekday  workingday  weathersit  temp  \
# 0           1   0     1   0        0        6           0           1  0.24
# 1           1   0     1   1        0        6           0           1  0.22
# 2           1   0     1   2        0        6           0           1  0.22
# 3           1   0     1   3        0        6           0           1  0.24
# 4           1   0     1   4        0        6           0           1  0.24
# ...       ...  ..   ...  ..      ...      ...         ...         ...   ...
# 17374       1   1    12  19        0        1           1           2  0.26
# 17375       1   1    12  20        0        1           1           2  0.26
# 17376       1   1    12  21        0        1           1           1  0.26
# 17377       1   1    12  22        0        1           1           1  0.26
# 17378       1   1    12  23        0        1           1           1  0.26
#
#         atemp   hum  windspeed  casual  registered  cnt
# ...

# %% [markdown]
# # QD Test Model

# %%
y=df['casual']
X=df.drop(['casual', 'yr'], axis='columns')

# %%
X_train, X_test, y_train, y_test=train_test_split(X, y,test_size= 0.2)

# %%
X_test
# Out:
#        season  mnth  hr  holiday  weekday  workingday  weathersit  temp  \
# 3397        2     5  11        0        4           1           1  0.74
# 14487       3     8  20        0        5           1           1  0.80
# 5639        3     8  10        0        0           0           1  0.70
# 980         1     2  12        0        0           0           1  0.36
# 16433       4    11  11        1        4           0           1  0.42
# ...       ...   ...  ..      ...      ...         ...         ...   ...
# 16857       4    12   4        0        1           1           2  0.38
# 11862       2     5  11        0        1           1           2  0.56
# 3680        2     6   6        0        2           1           1  0.60
# 9854        1     2  14        1        1           0           1  0.32
# 16605       4    11  16        0        4           1           1  0.36
#
#         atemp   hum  windspeed  registered  cnt
# 3397   0.6970  0.66     0.2239         124  160
# ...

# %%
ct=make_column_transformer((StandardScaler(), X.select_dtypes(include='number').columns),
                           remainder='passthrough')

# %%
lr = LinearRegression()

# %%
pl=make_pipeline(ct, lr)

# %%
pl.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('standardscaler',
#                                                   StandardScaler(),
#                                                   Index(['season', 'mnth', 'hr', 'holiday', 'weekday', 'workingday',
#        'weathersit', 'temp', 'atemp', 'hum', 'windspeed', 'registered', 'cnt'],
#       dtype='object'))])),
#                 ('linearregression', LinearRegression())])

# %%
pl.predict(X_test.loc[3397:3397, :])
# Out:
# array([36.])

# %%
y.loc[3397]
# Out:
# 36

# %%
cross_val_score(pl, X, y, cv=20).mean()
# Out:
# 1.0
